# %%
import os
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1539049588398_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-0-0-236.ap-southeast-2.compute.internal:20888/proxy/application_1539049588398_0002/">Link</a></td><td><a target="_blank" href="http://ip-10-0-0-11.ap-southeast-2.compute.internal:8042/node/containerlogs/container_1539049588398_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
